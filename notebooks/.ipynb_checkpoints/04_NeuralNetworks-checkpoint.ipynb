# %% [markdown]
# # Neural Network

# %% [markdown]
# <img src="images/nn.jpg" alt="Drawing" style="width: 700px;"/>
#
# <img src="images/neural-network.png" alt="Drawing" style="width: 700px;"/>

# %%
import numpy as np
np.random.seed(90)

import pandas as pd
import matplotlib.pyplot as plt

from sklearn.neural_network import MLPRegressor

# %matplotlib inline

# %%
from chemml.datasets import load_organic_density
smiles, density, features = load_organic_density()

X = features.values
y = density.values.reshape(-1)

# %%
max_iter = 500

mlpr = MLPRegressor(hidden_layer_sizes = (20,10), activation= 'relu', max_iter=max_iter)
mlpr.fit(X,y)

mlpt = MLPRegressor(hidden_layer_sizes = (20,10), activation= 'tanh', max_iter=max_iter)
mlpt.fit(X,y)

mlpl = MLPRegressor(hidden_layer_sizes = (20,10), activation= 'logistic', max_iter=max_iter)
mlpl.fit(X,y)

mlpi = MLPRegressor(hidden_layer_sizes = (20,10), activation= 'identity', max_iter=max_iter)
mlpi.fit(X,y)


# plot the fitted lines
fig = plt.figure(figsize=[12,8])
plt.subplot(2,2,1)
min_y = min(y)
max_y = max(y)
plt.plot([min_y,max_y],[min_y,max_y], label='R2: %f'%mlpr.score(X,y))
plt.scatter(mlpr.predict(X),y, c='k', label='relu')
plt.legend()
plt.subplot(2,2,2)
plt.plot([min_y,max_y],[min_y,max_y], label='R2: %f'%mlpt.score(X,y))
plt.scatter(mlpt.predict(X),y, c='k', label='tanh')
plt.legend()
plt.subplot(2,2,3)
plt.plot([min_y,max_y],[min_y,max_y], label='R2: %f'%mlpl.score(X,y))
plt.scatter(mlpl.predict(X),y, c='k', label='logistic')
plt.legend()
plt.subplot(2,2,4)
plt.plot([min_y,max_y],[min_y,max_y], label='R2: %f'%mlpi.score(X,y))
plt.scatter(mlpi.predict(X),y, c='k', label='identity')
plt.legend()
# Out:
# /anaconda2/envs/chemml_dev/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /anaconda2/envs/chemml_dev/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /anaconda2/envs/chemml_dev/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)

# %%
print ('# negative X:', (X<0).any().sum())
print ('maximum min of all features:', X.min().max())
# Out:
# # negative X: 1
# maximum min of all features: -0.003

# %%
(y<0).any().sum()
# Out:
# 0

# %% [markdown]
# ## Activation functions
# A list of activation functions:
# https://en.wikipedia.org/wiki/Activation_function
#
# - range of inputs and outputs
# - derivative at different input values

# %% [markdown]
# ## Impact of normalizing data

# %%
from sklearn import preprocessing

scalerSS = preprocessing.StandardScaler(copy=True, with_mean=True, with_std=True)
Xscaled = scalerSS.fit_transform(X)
yscaled = scalerSS.fit_transform(y.reshape(-1,1)).reshape(-1)

max_iter= 500

# define and fit models
mlpr = MLPRegressor(hidden_layer_sizes = (20,10), activation= 'relu', max_iter=max_iter)
mlpr.fit(Xscaled,yscaled)

mlpt = MLPRegressor(hidden_layer_sizes = (20,10), activation= 'tanh', max_iter=max_iter)
mlpt.fit(Xscaled,yscaled)

mlpl = MLPRegressor(hidden_layer_sizes = (20,10), activation= 'logistic', max_iter=max_iter)
mlpl.fit(Xscaled,yscaled)

mlpi = MLPRegressor(hidden_layer_sizes = (20,10), activation= 'identity', max_iter=max_iter)
mlpi.fit(Xscaled,yscaled)

# plot the fitted lines
fig = plt.figure(figsize=[12,8])
min_y = min(yscaled)
max_y = max(yscaled)

plt.subplot(2,2,1)
plt.plot([min_y,max_y],[min_y,max_y], label='R2: %f'%mlpr.score(Xscaled,yscaled))
plt.scatter(mlpr.predict(Xscaled),yscaled, c='k', label='relu')
plt.legend()

plt.subplot(2,2,2)
plt.plot([min_y,max_y],[min_y,max_y], label='R2: %f'%mlpt.score(Xscaled,yscaled))
plt.scatter(mlpt.predict(Xscaled),yscaled, c='k', label='tanh')
plt.legend()

plt.subplot(2,2,3)
plt.plot([min_y,max_y],[min_y,max_y], label='R2: %f'%mlpl.score(Xscaled,yscaled))
plt.scatter(mlpl.predict(Xscaled),yscaled, c='k', label='logistic')
plt.legend()

plt.subplot(2,2,4)
plt.plot([min_y,max_y],[min_y,max_y], label='R2: %f'%mlpi.score(Xscaled,yscaled))
plt.scatter(mlpi.predict(Xscaled),yscaled, c='k', label='identity')
plt.legend()

# %%
from sklearn import preprocessing

scalerSS = preprocessing.StandardScaler(copy=True, with_mean=True, with_std=True)
Xscaled = scalerSS.fit_transform(X)
yscaled = scalerSS.fit_transform(y.reshape(-1,1)).reshape(-1)



mlpr = MLPRegressor(hidden_layer_sizes = (20,10), activation= 'relu', alpha = 3)
mlpr.fit(Xscaled,yscaled)

mlpt = MLPRegressor(hidden_layer_sizes = (20,10), activation= 'tanh', alpha = 3)
mlpt.fit(Xscaled,yscaled)

mlpl = MLPRegressor(hidden_layer_sizes = (20,10), activation= 'logistic', alpha = 3)
mlpl.fit(Xscaled,yscaled)

mlpi = MLPRegressor(hidden_layer_sizes = (20,10), activation= 'identity', alpha = 3)
mlpi.fit(Xscaled,yscaled)


# plot the fitted lines
fig = plt.figure(figsize=[12,8])
plt.subplot(2,2,1)
plt.plot([-3,3],[-3,3], label='R2: %f'%mlpr.score(Xscaled,yscaled))
plt.scatter(mlpr.predict(Xscaled),yscaled, c='k', label='relu')
plt.legend()
plt.subplot(2,2,2)
plt.plot([-3,3],[-3,3], label='R2: %f'%mlpt.score(Xscaled,yscaled))
plt.scatter(mlpt.predict(Xscaled),yscaled, c='k', label='tanh')
plt.legend()
plt.subplot(2,2,3)
plt.plot([-3,3],[-3,3], label='R2: %f'%mlpl.score(Xscaled,yscaled))
plt.scatter(mlpl.predict(Xscaled),yscaled, c='k', label='logistic')
plt.legend()
plt.subplot(2,2,4)
plt.plot([-3,3],[-3,3], label='R2: %f'%mlpi.score(Xscaled,yscaled))
plt.scatter(mlpi.predict(Xscaled),yscaled, c='k', label='identity')
plt.legend()
# Out:
# /anaconda2/envs/chemml_dev/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /anaconda2/envs/chemml_dev/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /anaconda2/envs/chemml_dev/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /anaconda2/envs/chemml_dev/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)

# %% [markdown]
# ## Early stopping

# %%
mlpr = MLPRegressor(hidden_layer_sizes = (20,10), activation= 'relu', alpha = 1, max_iter=500, verbose = 1)
mlpr.fit(Xscaled,yscaled)

print (mlpr.score(Xscaled,yscaled))
# Out:
# Iteration 1, loss = 0.81714965
# Iteration 2, loss = 0.68366910
# Iteration 3, loss = 0.59078062
# Iteration 4, loss = 0.52090641
# Iteration 5, loss = 0.46091939
# Iteration 6, loss = 0.41366507
# Iteration 7, loss = 0.37129231
# Iteration 8, loss = 0.33710184
# Iteration 9, loss = 0.30889341
# Iteration 10, loss = 0.28638373
# Iteration 11, loss = 0.27133857
# Iteration 12, loss = 0.25781383
# Iteration 13, loss = 0.24661816
# Iteration 14, loss = 0.23682291
# Iteration 15, loss = 0.22734309
# Iteration 16, loss = 0.21783784
# Iteration 17, loss = 0.21027133
# Iteration 18, loss = 0.20342182
# Iteration 19, loss = 0.19726883
# Iteration 20, loss = 0.19251484
# Iteration 21, loss = 0.18787167
# Iteration 22, loss = 0.18367725
# Iteration 23, loss = 0.18041926
# Iteration 24, loss = 0.17652642
# Iteration 25, loss = 0.17365313
# Iteration 26, loss = 0.17093253
# Iteration 27, loss = 0.16812917
# Iteration 28, loss = 0.16586399
# Iteration 29, loss = 0.16328403
# Iteration 30, loss = 0.16090834
# Iteration 31, loss = 0.15880400
# Iteration 32, loss = 0.15687990
# Iteration 33, loss = 0.15508594
# Iteration 34, loss = 0.15306677
# Iteration 35, loss = 0.15142445
# Iteration 36, loss = 0.14951159
# Iteration 37, loss = 0.14789617
# Iteration 38, loss = 0.14613271
# Iteration 39, loss = 0.14471273
# Iteration 40, loss = 0.14300653
# Iteration 41, loss = 0.14128801
# Iteration 42, loss = 0.13968552
# Iteration 43, loss = 0.13835567
# Iteration 44, loss = 0.13668962
# Iteration 45, loss = 0.13534934
# Iteration 46, loss = 0.13449293
# Iteration 47, loss = 0.13260124
# Iteration 48, loss = 0.13148667
# Iteration 49, loss = 0.12973106
# Iteration 50, loss = 0.12872446
# Iteration 51, loss = 0.12689735
# Iteration 52, loss = 0.12632422
# Iteration 53, loss = 0.12452301
# Iteration 54, loss = 0.12319167
# Iteration 55, loss = 0.12209469
# Iteration 56, loss = 0.12085055
# Iteration 57, loss = 0.11986704
# Iteration 58, loss = 0.11844727
# Iteration 59, loss = 0.11717408
# Iteration 60, loss = 0.11595495
# Iteration 61, loss = 0.11508112
# Iteration 62, loss = 0.11369738
# Iteration 63, loss = 0.11265571
# Iteration 64, loss = 0.11146446
# Iteration 65, loss = 0.11035958
# Iteration 66, loss = 0.10942967
# Iteration 67, loss = 0.10825362
# Iteration 68, loss = 0.10733583
# Iteration 69, loss = 0.10627775
# Iteration 70, loss = 0.10527547
# Iteration 71, loss = 0.10432197
# Iteration 72, loss = 0.10306504
# Iteration 73, loss = 0.10206794
# Iteration 74, loss = 0.10114876
# Iteration 75, loss = 0.10020698
# Iteration 76, loss = 0.09925514
# Iteration 77, loss = 0.09832382
# Iteration 78, loss = 0.09740767
# Iteration 79, loss = 0.09652777
# Iteration 80, loss = 0.09570643
# Iteration 81, loss = 0.09508186
# Iteration 82, loss = 0.09401171
# Iteration 83, loss = 0.09297925
# Iteration 84, loss = 0.09217885
# Iteration 85, loss = 0.09125922
# Iteration 86, loss = 0.09032212
# Iteration 87, loss = 0.08946469
# Iteration 88, loss = 0.08868194
# Iteration 89, loss = 0.08786206
# Iteration 90, loss = 0.08704691
# Iteration 91, loss = 0.08614265
# Iteration 92, loss = 0.08552238
# Iteration 93, loss = 0.08457561
# Iteration 94, loss = 0.08398405
# Iteration 95, loss = 0.08307333
# Iteration 96, loss = 0.08234013
# Iteration 97, loss = 0.08161397
# Iteration 98, loss = 0.08103722
# Iteration 99, loss = 0.08018733
# Iteration 100, loss = 0.07955529
# Iteration 101, loss = 0.07879664
# Iteration 102, loss = 0.07798489
# Iteration 103, loss = 0.07751433
# Iteration 104, loss = 0.07679948
# Iteration 105, loss = 0.07609042
# Iteration 106, loss = 0.07571655
# Iteration 107, loss = 0.07489588
# Iteration 108, loss = 0.07415046
# Iteration 109, loss = 0.07361105
# Iteration 110, loss = 0.07292904
# Iteration 111, loss = 0.07218770
# Iteration 112, loss = 0.07185902
# Iteration 113, loss = 0.07119893
# Iteration 114, loss = 0.07070969
# Iteration 115, loss = 0.06983516
# Iteration 116, loss = 0.06934244
# Iteration 117, loss = 0.06867156
# Iteration 118, loss = 0.06842207
# Iteration 119, loss = 0.06819192
# Iteration 120, loss = 0.06718931
# Iteration 121, loss = 0.06685942
# Iteration 122, loss = 0.06644666
# Iteration 123, loss = 0.06539127
# Iteration 124, loss = 0.06497703
# Iteration 125, loss = 0.06463505
# Iteration 126, loss = 0.06408541
# Iteration 127, loss = 0.06339560
# Iteration 128, loss = 0.06292034
# Iteration 129, loss = 0.06255420
# Iteration 130, loss = 0.06194988
# Iteration 131, loss = 0.06139932
# Iteration 132, loss = 0.06104589
# Iteration 133, loss = 0.06042856
# Iteration 134, loss = 0.06006359
# Iteration 135, loss = 0.05962565
# Iteration 136, loss = 0.05906698
# Iteration 137, loss = 0.05866999
# Iteration 138, loss = 0.05829496
# Iteration 139, loss = 0.05771475
# Iteration 140, loss = 0.05726693
# Iteration 141, loss = 0.05708138
# Iteration 142, loss = 0.05662115
# Iteration 143, loss = 0.05607366
# Iteration 144, loss = 0.05594622
# Iteration 145, loss = 0.05575530
# Iteration 146, loss = 0.05517456
# Iteration 147, loss = 0.05519474
# Iteration 148, loss = 0.05453065
# Iteration 149, loss = 0.05411862
# Iteration 150, loss = 0.05355225
# Iteration 151, loss = 0.05313921
# Iteration 152, loss = 0.05264529
# Iteration 153, loss = 0.05213750
# Iteration 154, loss = 0.05179771
# Iteration 155, loss = 0.05162416
# Iteration 156, loss = 0.05118565
# Iteration 157, loss = 0.05078032
# Iteration 158, loss = 0.05040108
# Iteration 159, loss = 0.05006250
# Iteration 160, loss = 0.04970143
# Iteration 161, loss = 0.04937924
# Iteration 162, loss = 0.04914256
# Iteration 163, loss = 0.04870976
# Iteration 164, loss = 0.04854017
# Iteration 165, loss = 0.04801873
# Iteration 166, loss = 0.04774738
# Iteration 167, loss = 0.04742885
# Iteration 168, loss = 0.04725259
# Iteration 169, loss = 0.04705757
# Iteration 170, loss = 0.04674270
# Iteration 171, loss = 0.04654508
# Iteration 172, loss = 0.04593935
# Iteration 173, loss = 0.04552583
# Iteration 174, loss = 0.04526970
# Iteration 175, loss = 0.04495357
# Iteration 176, loss = 0.04465132
# Iteration 177, loss = 0.04434926
# Iteration 178, loss = 0.04410853
# Iteration 179, loss = 0.04396477
# Iteration 180, loss = 0.04376657
# Iteration 181, loss = 0.04334298
# Iteration 182, loss = 0.04299052
# Iteration 183, loss = 0.04281933
# Iteration 184, loss = 0.04268488
# Iteration 185, loss = 0.04244221
# Iteration 186, loss = 0.04200298
# Iteration 187, loss = 0.04179926
# Iteration 188, loss = 0.04155727
# Iteration 189, loss = 0.04127277
# Iteration 190, loss = 0.04100951
# Iteration 191, loss = 0.04076043
# Iteration 192, loss = 0.04049298
# Iteration 193, loss = 0.04020754
# Iteration 194, loss = 0.03990556
# Iteration 195, loss = 0.03967266
# Iteration 196, loss = 0.03956265
# Iteration 197, loss = 0.03940175
# Iteration 198, loss = 0.03942773
# Iteration 199, loss = 0.03880840
# Iteration 200, loss = 0.03882112
# Iteration 201, loss = 0.03829250
# Iteration 202, loss = 0.03814892
# Iteration 203, loss = 0.03798726
# Iteration 204, loss = 0.03771687
# Iteration 205, loss = 0.03750007
# Iteration 206, loss = 0.03731105
# Iteration 207, loss = 0.03740838
# Iteration 208, loss = 0.03719898
# Iteration 209, loss = 0.03703284
# Iteration 210, loss = 0.03650848
# Iteration 211, loss = 0.03643740
# Iteration 212, loss = 0.03613173
# Iteration 213, loss = 0.03613514
# Iteration 214, loss = 0.03592293
# Iteration 215, loss = 0.03564246
# Iteration 216, loss = 0.03514021
# Iteration 217, loss = 0.03554959
# Iteration 218, loss = 0.03509169
# Iteration 219, loss = 0.03480218
# Iteration 220, loss = 0.03463857
# Iteration 221, loss = 0.03451411
# Iteration 222, loss = 0.03420169
# Iteration 223, loss = 0.03388563
# Iteration 224, loss = 0.03377303
# Iteration 225, loss = 0.03368824
# Iteration 226, loss = 0.03377233
# Iteration 227, loss = 0.03372740
# Iteration 228, loss = 0.03314905
# Iteration 229, loss = 0.03330059
# Iteration 230, loss = 0.03313110
# Iteration 231, loss = 0.03270824
# Iteration 232, loss = 0.03298283
# Iteration 233, loss = 0.03233539
# Iteration 234, loss = 0.03234394
# Iteration 235, loss = 0.03221757
# Iteration 236, loss = 0.03188269
# Iteration 237, loss = 0.03181959
# Iteration 238, loss = 0.03152441
# Iteration 239, loss = 0.03206398
# Iteration 240, loss = 0.03239374
# Iteration 241, loss = 0.03139970
# Iteration 242, loss = 0.03136140
# Iteration 243, loss = 0.03107075
# Iteration 244, loss = 0.03088009
# Iteration 245, loss = 0.03066972
# Iteration 246, loss = 0.03049798
# Iteration 247, loss = 0.03000306
# Iteration 248, loss = 0.03003121
# Iteration 249, loss = 0.03006569
# Iteration 250, loss = 0.02968464
# Iteration 251, loss = 0.02950172
# Iteration 252, loss = 0.02969133
# Iteration 253, loss = 0.02970261
# Iteration 254, loss = 0.02933853
# Iteration 255, loss = 0.02917053
# Iteration 256, loss = 0.02910376
# Iteration 257, loss = 0.02909926
# Iteration 258, loss = 0.02884677
# Iteration 259, loss = 0.02856513
# Iteration 260, loss = 0.02851188
# Iteration 261, loss = 0.02851871
# Iteration 262, loss = 0.02817641
# Iteration 263, loss = 0.02801927
# Iteration 264, loss = 0.02802173
# Iteration 265, loss = 0.02804842
# Iteration 266, loss = 0.02768941
# Iteration 267, loss = 0.02796279
# Iteration 268, loss = 0.02780714
# Iteration 269, loss = 0.02784954
# Iteration 270, loss = 0.02713393
# Iteration 271, loss = 0.02722648
# Iteration 272, loss = 0.02709098
# Iteration 273, loss = 0.02695631
# Iteration 274, loss = 0.02668640
# Iteration 275, loss = 0.02689759
# Iteration 276, loss = 0.02683900
# Iteration 277, loss = 0.02713316
# Iteration 278, loss = 0.02634842
# Iteration 279, loss = 0.02641581
# Iteration 280, loss = 0.02722627
# Iteration 281, loss = 0.02658302
# Iteration 282, loss = 0.02612332
# Iteration 283, loss = 0.02597727
# Iteration 284, loss = 0.02601360
# Iteration 285, loss = 0.02587767
# Iteration 286, loss = 0.02560949
# Iteration 287, loss = 0.02557559
# Iteration 288, loss = 0.02539740
# Iteration 289, loss = 0.02529846
# Iteration 290, loss = 0.02514302
# Iteration 291, loss = 0.02496925
# Iteration 292, loss = 0.02499379
# Iteration 293, loss = 0.02492036
# Iteration 294, loss = 0.02468972
# Iteration 295, loss = 0.02472976
# Iteration 296, loss = 0.02480176
# Iteration 297, loss = 0.02450782
# Iteration 298, loss = 0.02457956
# Iteration 299, loss = 0.02476587
# Iteration 300, loss = 0.02432897
# Iteration 301, loss = 0.02447832
# Iteration 302, loss = 0.02449942
# Iteration 303, loss = 0.02432999
# Iteration 304, loss = 0.02434180
# Iteration 305, loss = 0.02420082
# Iteration 306, loss = 0.02384793
# Iteration 307, loss = 0.02377705
# Iteration 308, loss = 0.02373057
# Iteration 309, loss = 0.02351649
# Iteration 310, loss = 0.02356022
# Iteration 311, loss = 0.02361187
# Iteration 312, loss = 0.02343535
# Iteration 313, loss = 0.02346689
# Iteration 314, loss = 0.02325873
# Iteration 315, loss = 0.02325908
# Iteration 316, loss = 0.02348498
# Iteration 317, loss = 0.02307573
# Iteration 318, loss = 0.02287270
# Iteration 319, loss = 0.02301824
# Iteration 320, loss = 0.02279752
# Iteration 321, loss = 0.02279956
# Iteration 322, loss = 0.02267202
# Iteration 323, loss = 0.02294141
# Iteration 324, loss = 0.02280787
# Iteration 325, loss = 0.02269073
# Iteration 326, loss = 0.02261765
# Iteration 327, loss = 0.02254442
# Iteration 328, loss = 0.02244549
# Iteration 329, loss = 0.02269518
# Iteration 330, loss = 0.02238304
# Iteration 331, loss = 0.02236173
# Iteration 332, loss = 0.02240566
# Iteration 333, loss = 0.02247899
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# 0.9886010684954922

# %%
# with early_stopping
mlpr = MLPRegressor(hidden_layer_sizes = (20,10), activation= 'relu', alpha = 1, verbose = 1, early_stopping=True)
mlpr.fit(Xscaled,yscaled)

print (mlpr.score(Xscaled,yscaled))
# Out:
# Iteration 1, loss = 1.41766064
# Validation score: -1.429349
# Iteration 2, loss = 1.01654549
# Validation score: -0.816361
# Iteration 3, loss = 0.82343837
# Validation score: -0.354767
# Iteration 4, loss = 0.68789641
# Validation score: -0.079656
# Iteration 5, loss = 0.60135282
# Validation score: 0.108110
# Iteration 6, loss = 0.53954552
# Validation score: 0.264200
# Iteration 7, loss = 0.49728839
# Validation score: 0.398958
# Iteration 8, loss = 0.46403623
# Validation score: 0.499097
# Iteration 9, loss = 0.43415116
# Validation score: 0.558668
# Iteration 10, loss = 0.41028142
# Validation score: 0.599427
# Iteration 11, loss = 0.39254180
# Validation score: 0.633324
# Iteration 12, loss = 0.37405267
# Validation score: 0.668536
# Iteration 13, loss = 0.35537560
# Validation score: 0.699134
# Iteration 14, loss = 0.33908568
# Validation score: 0.725921
# Iteration 15, loss = 0.32530998
# Validation score: 0.751143
# Iteration 16, loss = 0.31387685
# Validation score: 0.773119
# Iteration 17, loss = 0.30468738
# Validation score: 0.791601
# Iteration 18, loss = 0.29459538
# Validation score: 0.808014
# Iteration 19, loss = 0.28616242
# Validation score: 0.824408
# Iteration 20, loss = 0.27730371
# Validation score: 0.838818
# Iteration 21, loss = 0.26993704
# Validation score: 0.853226
# Iteration 22, loss = 0.26377981
# Validation score: 0.864292
# Iteration 23, loss = 0.25697086
# Validation score: 0.869076
# Iteration 24, loss = 0.25116392
# Validation score: 0.874179
# Iteration 25, loss = 0.24538053
# Validation score: 0.883940
# Iteration 26, loss = 0.23982857
# Validation score: 0.887629
# Iteration 27, loss = 0.23457963
# Validation score: 0.889314
# Iteration 28, loss = 0.22955746
# Validation score: 0.897441
# Iteration 29, loss = 0.22470466
# Validation score: 0.902599
# Iteration 30, loss = 0.22095065
# Validation score: 0.903311
# Iteration 31, loss = 0.21554993
# Validation score: 0.904427
# Iteration 32, loss = 0.21110730
# Validation score: 0.909116
# Iteration 33, loss = 0.20684428
# Validation score: 0.916091
# Iteration 34, loss = 0.20410926
# Validation score: 0.920596
# Iteration 35, loss = 0.20027373
# Validation score: 0.918637
# Iteration 36, loss = 0.19741392
# Validation score: 0.922141
# Iteration 37, loss = 0.19346853
# Validation score: 0.928519
# Iteration 38, loss = 0.19159478
# Validation score: 0.930823
# Iteration 39, loss = 0.18863330
# Validation score: 0.928740
# Iteration 40, loss = 0.18599962
# Validation score: 0.926639
# Iteration 41, loss = 0.18467928
# Validation score: 0.930341
# Iteration 42, loss = 0.18203932
# Validation score: 0.933580
# Iteration 43, loss = 0.18052091
# Validation score: 0.932556
# Iteration 44, loss = 0.17822877
# Validation score: 0.930532
# Iteration 45, loss = 0.17746909
# Validation score: 0.933214
# Iteration 46, loss = 0.17511217
# Validation score: 0.935910
# Iteration 47, loss = 0.17382466
# Validation score: 0.933609
# Iteration 48, loss = 0.17236067
# Validation score: 0.933089
# Iteration 49, loss = 0.17082683
# Validation score: 0.936170
# Iteration 50, loss = 0.16935941
# Validation score: 0.937260
# Iteration 51, loss = 0.16806519
# Validation score: 0.937337
# Iteration 52, loss = 0.16722089
# Validation score: 0.937201
# Iteration 53, loss = 0.16586957
# Validation score: 0.940052
# Iteration 54, loss = 0.16496355
# Validation score: 0.941390
# Iteration 55, loss = 0.16374071
# Validation score: 0.938282
# Iteration 56, loss = 0.16250069
# Validation score: 0.939396
# Iteration 57, loss = 0.16102651
# Validation score: 0.943946
# Iteration 58, loss = 0.16018736
# Validation score: 0.942957
# Iteration 59, loss = 0.15933716
# Validation score: 0.941636
# Iteration 60, loss = 0.15810969
# Validation score: 0.945407
# Iteration 61, loss = 0.15705713
# Validation score: 0.945630
# Iteration 62, loss = 0.15588940
# Validation score: 0.942928
# Iteration 63, loss = 0.15528364
# Validation score: 0.943995
# Iteration 64, loss = 0.15401901
# Validation score: 0.948988
# Iteration 65, loss = 0.15322329
# Validation score: 0.950416
# Iteration 66, loss = 0.15205485
# Validation score: 0.947411
# Iteration 67, loss = 0.15274567
# Validation score: 0.948183
# Iteration 68, loss = 0.15043821
# Validation score: 0.954342
# Iteration 69, loss = 0.15198145
# Validation score: 0.952548
# Iteration 70, loss = 0.14846498
# Validation score: 0.949003
# Iteration 71, loss = 0.14870567
# Validation score: 0.953928
# Iteration 72, loss = 0.14677398
# Validation score: 0.956546
# Iteration 73, loss = 0.14787605
# Validation score: 0.952454
# Iteration 74, loss = 0.14473208
# Validation score: 0.949892
# Iteration 75, loss = 0.14499226
# Validation score: 0.954374
# Iteration 76, loss = 0.14378968
# Validation score: 0.955395
# Iteration 77, loss = 0.14274443
# Validation score: 0.951656
# Iteration 78, loss = 0.14199414
# Validation score: 0.954751
# Iteration 79, loss = 0.14057416
# Validation score: 0.957148
# Iteration 80, loss = 0.13992569
# Validation score: 0.956192
# Iteration 81, loss = 0.13885747
# Validation score: 0.956830
# Iteration 82, loss = 0.13773633
# Validation score: 0.959413
# Iteration 83, loss = 0.13707596
# Validation score: 0.958971
# Iteration 84, loss = 0.13627272
# Validation score: 0.958637
# Iteration 85, loss = 0.13534727
# Validation score: 0.960211
# Iteration 86, loss = 0.13453981
# Validation score: 0.960226
# Iteration 87, loss = 0.13387182
# Validation score: 0.958642
# Iteration 88, loss = 0.13326611
# Validation score: 0.957763
# Iteration 89, loss = 0.13228672
# Validation score: 0.960128
# Iteration 90, loss = 0.13163807
# Validation score: 0.961082
# Iteration 91, loss = 0.13065719
# Validation score: 0.959809
# Iteration 92, loss = 0.13033821
# Validation score: 0.960453
# Iteration 93, loss = 0.12930261
# Validation score: 0.961738
# Iteration 94, loss = 0.12867876
# Validation score: 0.959628
# Iteration 95, loss = 0.12763800
# Validation score: 0.960807
# Iteration 96, loss = 0.12657896
# Validation score: 0.962641
# Iteration 97, loss = 0.12633055
# Validation score: 0.962181
# Iteration 98, loss = 0.12554539
# Validation score: 0.961222
# Iteration 99, loss = 0.12472305
# Validation score: 0.964279
# Iteration 100, loss = 0.12403868
# Validation score: 0.963688
# Iteration 101, loss = 0.12314721
# Validation score: 0.962277
# Iteration 102, loss = 0.12239450
# Validation score: 0.964221
# Iteration 103, loss = 0.12207435
# Validation score: 0.962807
# Iteration 104, loss = 0.12104314
# Validation score: 0.960437
# Iteration 105, loss = 0.12094047
# Validation score: 0.964826
# Iteration 106, loss = 0.12075718
# Validation score: 0.965399
# Iteration 107, loss = 0.11945730
# Validation score: 0.961446
# Iteration 108, loss = 0.11915939
# Validation score: 0.961082
# Iteration 109, loss = 0.11756007
# Validation score: 0.965075
# Iteration 110, loss = 0.11704123
# Validation score: 0.965316
# Iteration 111, loss = 0.11571636
# Validation score: 0.965466
# Iteration 112, loss = 0.11535950
# Validation score: 0.966478
# Iteration 113, loss = 0.11445228
# Validation score: 0.967103
# Iteration 114, loss = 0.11384649
# Validation score: 0.965330
# Iteration 115, loss = 0.11360021
# Validation score: 0.965627
# Iteration 116, loss = 0.11293689
# Validation score: 0.966289
# Iteration 117, loss = 0.11215384
# Validation score: 0.964779
# Iteration 118, loss = 0.11103001
# Validation score: 0.965855
# Iteration 119, loss = 0.11051337
# Validation score: 0.966811
# Iteration 120, loss = 0.10980985
# Validation score: 0.966724
# Iteration 121, loss = 0.10948431
# Validation score: 0.966957
# Iteration 122, loss = 0.10860793
# Validation score: 0.968220
# Iteration 123, loss = 0.10788401
# Validation score: 0.967186
# Iteration 124, loss = 0.10731259
# Validation score: 0.964263
# Iteration 125, loss = 0.10690809
# Validation score: 0.964735
# Iteration 126, loss = 0.10587663
# Validation score: 0.967099
# Iteration 127, loss = 0.10540263
# Validation score: 0.967292
# Iteration 128, loss = 0.10453282
# Validation score: 0.966819
# Iteration 129, loss = 0.10426704
# Validation score: 0.967457
# Iteration 130, loss = 0.10331584
# Validation score: 0.969475
# Iteration 131, loss = 0.10326957
# Validation score: 0.968284
# Iteration 132, loss = 0.10210057
# Validation score: 0.966516
# Iteration 133, loss = 0.10163479
# Validation score: 0.968405
# Iteration 134, loss = 0.10114607
# Validation score: 0.967367
# Iteration 135, loss = 0.10060571
# Validation score: 0.965669
# Iteration 136, loss = 0.10006938
# Validation score: 0.967492
# Iteration 137, loss = 0.09949005
# Validation score: 0.967482
# Iteration 138, loss = 0.09855585
# Validation score: 0.966978
# Iteration 139, loss = 0.09806980
# Validation score: 0.968898
# Iteration 140, loss = 0.09766741
# Validation score: 0.968998
# Iteration 141, loss = 0.09680969
# Validation score: 0.968449
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# 0.9810337380930186

# %% [markdown]
# ## Keras

# %%
from keras.layers import Input, Dense, Concatenate
from keras.models import Sequential, Model
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from keras.initializers import glorot_uniform
from keras import regularizers
from keras import losses
from keras import backend as K
# Out:
# Using TensorFlow backend.

# %%
def model_creator(nneurons=features.shape[1], activation=['relu','tanh'], lr = 0.001):
    # branch 1
    b1_in = Input(shape=(nneurons, ), name='inp1')
    l1 = Dense(12, name='l1', activation=activation[0])(b1_in)
    b1_l1 = Dense(6, name='b1_l1', activation=activation[0])(l1)
    b1_l2 = Dense(3, name='b1_l2', activation=activation[0])(b1_l1)
    # branch 2
    b2_l1 = Dense(16, name='b2_l1', activation=activation[1])(l1)
    b2_l2 = Dense(8, name='b2_l2', activation=activation[1])(b2_l1)
    # merge branches
    merged = Concatenate(name='merged')([b1_l2, b2_l2])
    # linear output
    out = Dense(1, name='outp', activation='linear')(merged)
    ###
    model = Model(inputs = b1_in, outputs = out)
    adam = Adam(lr=lr, beta_1=0.9, beta_2=0.999, epsilon=1e-8, decay=0.0)
    model.compile(optimizer = adam,
                  loss = 'mean_squared_error',
                  metrics=['mean_absolute_error'])
    return model

# %%
m = model_creator()
m.summary()
# Out:
# WARNING:tensorflow:From /anaconda2/envs/chemml_dev/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# inp1 (InputLayer)               (None, 200)          0
# __________________________________________________________________________________________________
# l1 (Dense)                      (None, 12)           2412        inp1[0][0]
# __________________________________________________________________________________________________
# b1_l1 (Dense)                   (None, 6)            78          l1[0][0]
# __________________________________________________________________________________________________
# b2_l1 (Dense)                   (None, 16)           208         l1[0][0]
# __________________________________________________________________________________________________
# b1_l2 (Dense)                   (None, 3)            21          b1_l1[0][0]
# __________________________________________________________________________________________________
# b2_l2 (Dense)                   (None, 8)            136         b2_l1[0][0]
# __________________________________________________________________________________________________
# merged (Concatenate)            (None, 11)           0           b1_l2[0][0]
#                                                                  b2_l2[0][0]
# __________________________________________________________________________________________________
# outp (Dense)                    (None, 1)            12          merged[0][0]
# ==================================================================================================
# Total params: 2,867
# Trainable params: 2,867
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# You need to install `pydot`. For example with `pip install pydot`.
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot

SVG(model_to_dot(m).create(prog='dot', format='svg'))
