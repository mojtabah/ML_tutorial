# %%
# example from https://github.com/ubdsgroup/ubmlcourse/blob/master/notebooks/KernelMethodsIntro.ipynb

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
# %matplotlib inline
# Out:
# /Users/mojtabahaghighatlari/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
x1 = 0
sigma = 0.5
x2 = np.linspace(-10,10,100)
k = np.zeros((x2.shape[0],1))
for sigma in [0.1,0.5,0.9,2]:
    for i in range(k.shape[0]):
        k[i] = np.exp(-0.5*sigma**2*((x1 - x2[i])**2));
    plt.plot(x2,k,label='$\sigma$='+str(sigma))
plt.legend()

# %%
X = np.linspace(-10,10,21)
y = np.zeros((X.shape[0],1))
y[5:16] = 1
plt.plot(X[np.where(y == 0)[0]],y[np.where(y == 0)[0]],'ro')
plt.plot(X[np.where(y == 1)[0]],0*y[np.where(y == 1)[0]],'b+')

# %%
X1 = np.vstack((X,X**2)).transpose()
plt.scatter(X1[np.where(y == 0)[0],0],X1[np.where(y == 0)[0],1],c='r',marker='o')
plt.scatter(X1[np.where(y == 1)[0],0],X1[np.where(y == 1)[0],1],c='b',marker='+')

# %%
plt.scatter(X1[np.where(y == 0)[0],0],X1[np.where(y == 0)[0],1],c='r',marker='o')
plt.scatter(X1[np.where(y == 1)[0],0],X1[np.where(y == 1)[0],1],c='b',marker='+')
plt.plot([-10,10],[30,30])

# %%
from sklearn import svm
clf = svm.SVC(kernel='poly', degree=2)
X = X.reshape(-1,1)
clf.fit(X,y)
print clf.score(X,y)
plt.scatter(X, clf.predict(X))
# Out:
# 1.0

# %% [markdown]
# ## Impact of hyperparameter selection

# %%
X2 = np.vstack((X,X**3)).transpose()
plt.scatter(X2[np.where(y == 0)[0],0],X2[np.where(y == 0)[0],1],c='r',marker='o')
plt.scatter(X2[np.where(y == 1)[0],0],X2[np.where(y == 1)[0],1],c='b',marker='+')

# %%
from sklearn import svm
clf = svm.SVC(kernel='poly', degree=3)
X = X.reshape(-1,1)
clf.fit(X,y)
print clf.score(X,y)
plt.scatter(X, clf.predict(X))
# Out:
# 0.52380952381
